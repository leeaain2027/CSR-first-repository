# %%
# 필요한 패키지 import 하기
import os 
import cv2 
import matplotlib.pyplot as plt
import numpy as np
import dlib

# 사진 불러오기 + 화면에 보여주기
home_dir = os.getenv('HOME')
input_dir  = os.path.join(home_dir, 'work/camera_sticker/images/input')
output_dir = os.path.join(home_dir, 'work/camera_sticker/images/output')
os.makedirs(output_dir, exist_ok=True)

# 모델/스티커는 반복문 밖에서 1번만
detector_hog = dlib.get_frontal_face_detector()

model_path = os.path.join(home_dir, 'work/camera_sticker/models/shape_predictor_68_face_landmarks.dat')
landmark_predictor = dlib.shape_predictor(model_path)

sticker_path = os.path.join(home_dir, 'work/camera_sticker/images/cat-whiskers.png')
img_sticker_origin = cv2.imread(sticker_path, cv2.IMREAD_UNCHANGED)

valid_ext = (".jpg", ".jpeg", ".png", ".bmp", ".webp")
image_files = [f for f in os.listdir(input_dir) if f.lower().endswith(valid_ext)]
image_files.sort()
print(image_files)

SHOW_DEBUG = True          # 중간 과정 화면 출력 켜기/끄기
SHOW_LIMIT = 10             # 몇 장까지만 보여줄지 (예: 2장이면 2장만 4단계 출력)
shown_count = 0

def show_4steps(filename, img_original, img_box, img_landmark, img_result):
    fig = plt.figure(figsize=(12, 4))

    ax2 = fig.add_subplot(1, 4, 2)
    ax2.set_title("2) Face box")
    ax2.imshow(cv2.cvtColor(img_box, cv2.COLOR_BGR2RGB))
    ax2.axis("off")

    ax3 = fig.add_subplot(1, 4, 3)
    ax3.set_title("3) Landmarks")
    ax3.imshow(cv2.cvtColor(img_landmark, cv2.COLOR_BGR2RGB))
    ax3.axis("off")

    ax4 = fig.add_subplot(1, 4, 4)
    ax4.set_title("4) Sticker result")
    ax4.imshow(cv2.cvtColor(img_result, cv2.COLOR_BGR2RGB))
    ax4.axis("off")

    fig.suptitle(filename)
    fig.tight_layout()
    plt.show()


for filename in image_files:
    my_image_path = os.path.join(input_dir, filename)

    # ✅ 1) img_bgr 먼저 만들기
    img_bgr = cv2.imread(my_image_path)
    if img_bgr is None:
        print(f"[스킵] 읽기 실패: {filename}")
        continue

    # 2) 여기서부터 복사본 만들기 (정답 위치)
    img_original = img_bgr.copy()   # 1) 원본
    img_box = img_bgr.copy()        # 2) 얼굴 박스
    img_landmark = img_bgr.copy()   # 3) 랜드마크
    img_result = img_bgr.copy()     # 4) 스티커 결과

    # dlib용 RGB
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

    import hashlib

    def md5_arr(a):
        return hashlib.md5(a.tobytes()).hexdigest()
    
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    
    print(filename, "img_rgb md5:", md5_arr(img_rgb), "shape:", img_rgb.shape, "mean:", round(float(img_rgb.mean()), 2))
    dlib_rects = detector_hog(img_rgb, 1)
    print(filename, "faces:", len(dlib_rects))

    if len(dlib_rects) == 0:
        print(f"[스킵] 얼굴 없음: {filename}")
        cv2.imwrite(os.path.join(output_dir, filename), img_result)
        continue

    box_dir = os.path.join(output_dir, "box")
    landmark_dir = os.path.join(output_dir, "landmark")
    result_dir = os.path.join(output_dir, "result")
    
    os.makedirs(box_dir, exist_ok=True)
    os.makedirs(landmark_dir, exist_ok=True)
    os.makedirs(result_dir, exist_ok=True)

    print("image_files:", image_files)
    print("개수:", len(image_files))
    
    # 얼굴마다 스티커 붙이기
    for dlib_rect in dlib_rects:
        print(f"[{filename}] ENTER face loop")
        
        # ✅ (추가) 얼굴 박스 그리기
        l, t, r, b = dlib_rect.left(), dlib_rect.top(), dlib_rect.right(), dlib_rect.bottom()
        cv2.rectangle(img_box, (l, t), (r, b), (0, 255, 0), 2)
        print("박스 그림")
        cv2.rectangle(img_landmark, (l, t), (r, b), (0, 255, 0), 2)

        points = landmark_predictor(img_rgb, dlib_rect)
        landmark = [(p.x, p.y) for p in points.parts()]
        # ✅ (추가) 랜드마크 점 찍기
        for (lx, ly) in landmark:
            cv2.circle(img_landmark, (lx, ly), 2, (0, 255, 255), -1)

        # ✅ (추가) 코(30번) 강조
        x, y = landmark[30]
        cv2.circle(img_landmark, (x, y), 5, (0, 0, 255), -1)

        # 얼굴 폭 기준 스티커 크기
        w = int(dlib_rect.width() * 0.8)
        h = w
        if w <= 0:
            continue
            
        img_sticker = cv2.resize(img_sticker_origin, (w, h))

        sticker_x = int(w * 0.5)
        sticker_y = int(h * 0.45)

        refined_x = x - sticker_x
        refined_y = y - sticker_y

        # 🔍 image9이 왜 탈락하는지 확인하는 핵심 로그 (여기!)
        print(f"[{filename}] w={w} refined=({refined_x},{refined_y}) img=({img_result.shape[1]},{img_result.shape[0]})")
        
        if refined_x < 0 or refined_y < 0:
            print(f"[{filename}] SKIP: negative refined")
            continue
        
        if refined_x + w > img_result.shape[1] or refined_y + h > img_result.shape[0]:
            print(f"[{filename}] SKIP: out of bounds")
            continue
        
        print(f"[{filename}] OK: will blend")

        # ✅ 합성 (img_bgr에 1번만)
        roi = img_result[refined_y:refined_y+h, refined_x:refined_x+w].astype(np.float32)
        sticker_bgr = img_sticker[:, :, :3].astype(np.float32)
        alpha = (img_sticker[:, :, 3].astype(np.float32) / 255.0)[:, :, None]

        blended = alpha * sticker_bgr + (1 - alpha) * roi
        img_result[refined_y:refined_y+h, refined_x:refined_x+w] = blended.astype(np.uint8)

        # 단계별 결과 저장 (핵심)
        cv2.imwrite(os.path.join(box_dir, filename), img_box)
        cv2.imwrite(os.path.join(landmark_dir, filename), img_landmark)
        cv2.imwrite(os.path.join(result_dir, filename), img_result)

    print("diff(box):", np.sum(np.abs(img_box.astype(np.int32) - img_original.astype(np.int32))))
    print("diff(lm):",  np.sum(np.abs(img_landmark.astype(np.int32) - img_original.astype(np.int32))))
    print("diff(res):", np.sum(np.abs(img_result.astype(np.int32) - img_original.astype(np.int32))))

    # 저장
    # ✅ (추가) 4단계 화면 출력 (처음 SHOW_LIMIT장만)
    if SHOW_DEBUG and shown_count < SHOW_LIMIT:
        show_4steps(filename, img_original, img_box, img_landmark, img_result)
        shown_count += 1

    # ✅ (수정) 저장은 img_result로
    save_path = os.path.join(output_dir, filename)
    cv2.imwrite(save_path, img_result)
# Out:
# ['image1.jpg', 'image10.png', 'image2.png', 'image3.png', 'image4.png', 'image5.png', 'image6.png', 'image7.png', 'image8.png', 'image9.png']
# image1.jpg img_rgb md5: d4e60ab1a935900e330a4c37c7aa2653 shape: (3088, 2316, 3) mean: 129.9
# image1.jpg faces: 1
# image_files: ['image1.jpg', 'image10.png', 'image2.png', 'image3.png', 'image4.png', 'image5.png', 'image6.png', 'image7.png', 'image8.png', 'image9.png']
# 개수: 10
# [image1.jpg] ENTER face loop
# 박스 그림
# [image1.jpg] w=767 refined=(712,928) img=(2316,3088)
# [image1.jpg] OK: will blend
# diff(box): 4558559
# diff(lm): 4905460
# diff(res): 17210381
# image10.png img_rgb md5: d41a9b4f04f180c392630a5d71d02364 shape: (2000, 1500, 3) mean: 129.48
# image10.png faces: 1
# image_files: ['image1.jpg', 'image10.png', 'image2.png', 'image3.png', 'image4.png', 'image5.png', 'image6.png', 'image7.png', 'image8.png', 'image9.png']
# 개수: 10
# [image10.png] ENTER face loop
# 박스 그림
# [image10.png] w=532 refined=(443,585) img=(1500,2000)
# [image10.png] OK: will blend
# diff(box): 2860710
# diff(lm): 3218736
# diff(res): 8121473
# image2.png img_rgb md5: 604b78f0d4098df6a01dea914fcc5496 shape: (2000, 1500, 3) mean: 140.39
# image2.png faces: 1
# image_files: ['image1.jpg', 'image10.png', 'image2.png', 'image3.png', 'image4.png', 'image5.png', 'image6.png', 'image7.png', 'image8.png', 'image9.png']
# 개수: 10
# [image2.png] ENTER face loop
# 박스 그림
# [image2.png] w=444 refined=(431,416) img=(1500,2000)
# [image2.png] OK: will blend
# diff(box): 2777502
# diff(lm): 3114432
# diff(res): 6704891
# image3.png img_rgb md5: e0f83d9ce86e2095b50d23fbfce7b053 shape: (2000, 1500, 3) mean: 124.29
# image3.png faces: 1
# image_files: ['image1.jpg', 'image10.png', 'image2.png', 'image3.png', 'image4.png', 'image5.png', 'image6.png', 'image7.png', 'image8.png', 'image9.png']
# 개수: 10
# [image3.png] ENTER face loop
# 박스 그림
# [image3.png] w=532 refined=(743,589) img=(1500,2000)
# [image3.png] OK: will blend
# diff(box): 3333340
# diff(lm): 3680609
# diff(res): 9653134
# image4.png img_rgb md5: 8b0892193478ab6a18ff5b505fb621b1 shape: (2000, 1500, 3) mean: 121.03
# image4.png faces: 1
# image_files: ['image1.jpg', 'image10.png', 'image2.png', 'image3.png', 'image4.png', 'image5.png', 'image6.png', 'image7.png', 'image8.png', 'image9.png']
# 개수: 10
# [image4.png] ENTER face loop
# 박스 그림
# [image4.png] w=532 refined=(355,805) img=(1500,2000)
# [image4.png] OK: will blend
# diff(box): 2959124
# diff(lm): 3322982
# diff(res): 8245595
# image5.png img_rgb md5: 0e6ac40de24918a25a11ab78585bcbaa shape: (1536, 1024, 3) mean: 175.29
# image5.png faces: 1
# image_files: ['image1.jpg', 'image10.png', 'image2.png', 'image3.png', 'image4.png', 'image5.png', 'image6.png', 'image7.png', 'image8.png', 'image9.png']
# 개수: 10
# [image5.png] ENTER face loop
# 박스 그림
# [image5.png] w=104 refined=(491,155) img=(1024,1536)
# [image5.png] OK: will blend
# diff(box): 637597
# diff(lm): 949372
# diff(res): 395166
# image6.png img_rgb md5: baf4d2403cc3c54371e130f0e6f92f04 shape: (2000, 1500, 3) mean: 107.22
# image6.png faces: 1
# image_files: ['image1.jpg', 'image10.png', 'image2.png', 'image3.png', 'image4.png', 'image5.png', 'image6.png', 'image7.png', 'image8.png', 'image9.png']
# 개수: 10
# [image6.png] ENTER face loop
# 박스 그림
# [image6.png] w=920 refined=(223,392) img=(1500,2000)
# [image6.png] OK: will blend
# diff(box): 5544626
# diff(lm): 5889734
# diff(res): 24645824
# image7.png img_rgb md5: 53d981e4e7fa59e597fb2b7fc0c08742 shape: (2000, 1500, 3) mean: 130.01
# image7.png faces: 0
# [스킵] 얼굴 없음: image7.png
# image8.png img_rgb md5: 9d13f00e54392795a2111dfa5ac6e88d shape: (2000, 1500, 3) mean: 151.28
# image8.png faces: 0
# [스킵] 얼굴 없음: image8.png
# image9.png img_rgb md5: 0c592ec8fa2cf046598452c7d3702f79 shape: (2000, 1500, 3) mean: 72.64
# image9.png faces: 1
# image_files: ['image1.jpg', 'image10.png', 'image2.png', 'image3.png', 'image4.png', 'image5.png', 'image6.png', 'image7.png', 'image8.png', 'image9.png']
# 개수: 10
# [image9.png] ENTER face loop
# 박스 그림
# [image9.png] w=532 refined=(445,585) img=(1500,2000)
# [image9.png] OK: will blend
# diff(box): 2593295
# diff(lm): 2988245
# diff(res): 4293197
